# %% [markdown]
# # A1 Documentation:

# %% [markdown]
# # A2 List of basic modes:

# %% [markdown]
# # A3  Open for reading:

# %%
'r'
# Out:
# 'r'

# %% [markdown]
# # A4 Open for writing(it truncates the file first):

# %%
'w'
# Out:
# 'w'

# %% [markdown]
# # # A5 Open for exclusive creation: error when file exists

# %%
'x'
# Out:
# 'x'

# %% [markdown]
# # A6 Open for writing, appending to the end of the file if it exists:

# %%
'a'# append
# Out:
# 'a'

# %% [markdown]
# # A7 Binary

# %%
'b'
# Out:
# 'b'

# %% [markdown]
# # A8 Text mode:

# %%
't'# but also default
# Out:
# 't'

# %% [markdown]
# # A9 Open for updating(reading and writing):

# %%
'+'
# Out:
# '+'
