# %% [markdown]
# # A1
#
# ## Saving files

# %% [markdown]
# # A2
#
# ## Python doesn't communicate with OS's directly but by intermediary functions :

# %% [markdown]
# ### it used libraries to handle multiple file system structures

# %% [markdown]
# # A3
#
# ## Handles and streams

# %% [markdown]
# ### opening and closing the files

# %% [markdown]
# # A4
#
# ## File handling (I/O - input output) objects in Python :

# %% [markdown]
# ### IOBase -> [RawIOBase;BufferedIOBase;TextIOBase]

# %% [markdown]
# # A5
#
# ## Most general types of files:

# %% [markdown]
# ### text files and binary files
