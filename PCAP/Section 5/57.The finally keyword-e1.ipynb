# %% [markdown]
# # A1
#
# ## Try /except blocks can also use a finally keyword- how does it work?

# %% [markdown]
# ### It allows us to perform an action irregardless of whether the code in the try clause worked or not

# %%
try:
    print(1/0)
except:
    print("Do not divide by zero")
else:
    print("You can divide by other numbers")
finally:
    print("Finale")
# Out:
# Do not divide by zero
# Finale
