# %% [markdown]
# # A1
#
# ## What is a syntax error?

# %% [markdown]
# ### It's an in-built generic exception used when the syntax of the program doesn't abide by the program rules

# %%
if True:
print('x')
# Out:
#   Cell In[3], line 2
#     print('x')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# # A2
#
# ## What is a value error?

# %% [markdown]
# ### value provided by the user is not accepted by the method used in the program syntax

# %% [markdown]
# # A3
#
# ## What is an exception?

# %% [markdown]
# ### An exception is an event which occurs during the execution of a program that disrupts the normal flow of the program instructions

# %% [markdown]
# # A4
#
# ## Handling exceptions - try/except syntax:

# %% [raw]
# try:
#     value = int(input('Enter an int:'))
#     print(1/value)
# except:
#     print('Not an integer!')

# %%
try:
    value = int(input('Enter an int:'))
    print(1/value)
except:
    print('Not an integer!')
# Out:
# Enter an int: a
# Not an integer!

# %% [markdown]
# # A5
#
# ## Zero division error:

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # A6
#
# ## multiple except branches

# %%
try:
    value = int(input('Enter an int:'))
    print(1/value)
except ValueError:
    print('Not an integer!')
except ZeroDivisionError:
    print('Provide value other than zero')
except:
# Out:
# Enter an int: 0
# Provide value other than zero

# %% [markdown]
# # A7
#
# ## Where to put the genera; 'except' block?

# %%
### last
