# %% [markdown]
# # A1
#
# ## a hierarchy of exceptions - the highest level exception will be called the last :

# %% [markdown]
# Base exception - 1 n\
# Exception,SystemExit,KeybordInterrupt...-2\
# ArithmeticError,LookupError,TypeError,ValueError\
# ZeroDivisionError,IndexError,KeyError-4\

# %% [markdown]
# # A2
#
# ## What is SysExit and what it allows you to do?

# %%
import sys

user_name = input("Name?")
if user_name == '':
    print('ErrorEmpty!')
    sys.exit()
print("Hello",user_name)
# Out:
# Name?
# ErrorEmpty!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Nouser\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # A3
#
# ## difference between BaseException and Exception

# %% [markdown]
# ### BaseException is usually not accessible and is used internally by python, Exception is used as a template for the rest of the exceptions

# %% [markdown]
# # A4
#
# ## KeyError and IndexError are children of LookupError when working with lists and other collections

# %%
letters = ['a','b','c']
print(letters[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 letters = ['a','b','c']
# ----> 2 print(letters[4])
#
# IndexError: list index out of range

# %%
letters2 = {1:'a',2:'b',3:'c'}

# %%
print(letters2[1])
# Out:
# a

# %%
print(letters2[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(letters2[4])
#
# KeyError: 4

# %% [markdown]
# # A5
#
# ## TypeError and ValueError

# %%
age = input("?")
print(age+20)
# Out:
# ? a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 age = input("?")
# ----> 2 print(age+20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = input("?")
age_int = int(input("?"))
# Out:
# ? 1
# ? a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 age = input("?")
# ----> 2 age_int = int(input("?"))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# ### Only takes values of int of a certain kind and discriminates
