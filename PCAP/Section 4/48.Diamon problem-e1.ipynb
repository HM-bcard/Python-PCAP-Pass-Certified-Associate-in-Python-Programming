# %% [markdown]
# # A1
#
# ## What is the diamond problem?

# %% [markdown]
# ### One of the problems arising with multiple inheritance

# %% [markdown]
# # A2
#
# ## Explanation:

# %%
class Vehicle:
    def show_power_type(self):
        print("Multiple")

class ElectricVehicle(Vehicle):
    def show_power_type(self):
        print("Battery")

class PetrolVehicle(Vehicle):
    def show_power_type(self):
        print("Petroleum")
class Hybrid(ElectricVehicle,PetrolVehicle):
    pass

# %%
prius = Hybrid()
prius.show_power_type()
# Out:
# Battery

# %%
class Vehicle:
    def show_power_type(self):
        print("Multiple")

class ElectricVehicle(Vehicle):
    def show_power_type(self):
        print("Battery")

class PetrolVehicle(Vehicle):
    def show_power_type(self):
        print("Petroleum")
class Hybrid(PetrolVehicle,ElectricVehicle):
    pass
prius = Hybrid()
prius.show_power_type()
# Out:
# Petroleum

# %% [markdown]
# # A3
#
# ## The diamond problem is resolved utilizing the MRO order

# %% [markdown]
# # A4
#
# ## Python MRO:

# %% [markdown]
# ### 1. Object
# ### 2. Superclasses right to left
# ### 3. Error
