# %% [markdown]
# # A1
#
# ## there is a standard library that python checks when we try to import a module

# %% [markdown]
# ### Displaying all modules:

# %%
import sys

sys.path
# Out:
# ['C:\\Users\\Nouser\\anaconda3\\python311.zip',
#  'C:\\Users\\Nouser\\anaconda3\\DLLs',
#  'C:\\Users\\Nouser\\anaconda3\\Lib',
#  'C:\\Users\\Nouser\\anaconda3',
#  '',
#  'C:\\Users\\Nouser\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\Nouser\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\Nouser\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Nouser\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # A2
#
# ## Python looks only on the 'path' internal variable
# ### If the module isn't added to path variable, it won't be displayed

# %%
import secret_module
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import secret_module
#
# ModuleNotFoundError: No module named 'secret_module'

# %% [markdown]
# # A3
#
# ## adding own modules to the path

# %% [markdown]
# import sys
#
# sys.path.append('secret')
#
# import secret_module

# %% [markdown]
# # A4
#
# ## adding relative and absolute paths

# %% [markdown]
# ### absolute path :
# path in relation to root/c:
# such as:
# 'C:\\\Users\\\\user\\\\folder\\\..' # double slashes because of the slash working as an escape character
#
# a relative path i sa path relative to the current folder:
#
# if the folder is in the same directory, you just need to specify the folder(directory) name
#
# sys.path.append("C:\\Users\\user\\folder\\..")
#
# vs
#
# sys.path.append('secretfolder')

# %% [markdown]
# # A5
#
# ## relative path up and down:
#
# ### relative_path: "..\\secret"
