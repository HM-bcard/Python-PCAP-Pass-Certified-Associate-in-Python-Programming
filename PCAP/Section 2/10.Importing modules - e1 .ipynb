# %% [markdown]
# # A1

# %%
import sys

# %% [markdown]
# # A2

# %% [markdown]
# Importing multiple modules:

# %%
import sys
import math

# %% [markdown]
# or

# %%
import sys,math

# %% [markdown]
# # A3

# %% [markdown]
# Listing entities:

# %%
import sys

for name in dir(sys):
    print(name, end ='\t')
# Out:
# __breakpointhook__	__displayhook__	__doc__	__excepthook__	__interactivehook__	__loader__	__name__	__package__	__spec__	__stderr__	__stdin__	__stdout__	__unraisablehook__	_base_executable	_clear_type_cache	_current_exceptions	_current_frames	_debugmallocstats	_enablelegacywindowsfsencoding	_framework	_getframe	_getquickenedcount	_git	_home	_stdlib_dir	_vpath	_xoptions	addaudithook	api_version	argv	audit	base_exec_prefix	base_prefix	breakpointhook	builtin_module_names	byteorder	call_tracing	copyright	displayhook	dllhandle	dont_write_bytecode	exc_info	excepthook	exception	exec_prefix	executable	exit	flags	float_info	float_repr_style	get_asyncgen_hooks	get_coroutine_origin_tracking_depth	get_int_max_str_digits	getallocatedblocks	getdefaultencoding	getfilesystemencodeerrors	getfilesystemencoding	getprofile	getrecursionlimit	getrefcount	getsizeof	getswitchinterval	gettrace	getwindowsversion	hash_info	hexversion	implementation	int_info	intern	is_finalizing	maxsize	maxunicode	meta_path	modul
# ...

# %% [markdown]
# # A4
#
# ## Utilizing a module:

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Nouser\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # A5
#
# ## Utilizing an atribute  that doesn't exist

# %%
sys.error2()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sys.error2()
#
# AttributeError: module 'sys' has no attribute 'error2'

# %% [markdown]
# # A6
#
# ## Building a custom made function with the module name:

# %%
import sys

def exit():
    print('Exiting')

exit()
sys.exit()
# Out:
# Exiting
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# # A7
#
# ## Importing a specific entity from a module:

# %%
from sys import exit,stdin,stdout


def exit():
    print('Exiting')

exit()
sys.exit()
# Out:
# Exiting
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# New function overrides the imported function

# %% [markdown]
# # A8
#
# ## Importing all entities:

# %%
from sys import *

# %% [markdown]
# # A9
#
# ## Aliasing during import:

# %%
import sys as s

s.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
