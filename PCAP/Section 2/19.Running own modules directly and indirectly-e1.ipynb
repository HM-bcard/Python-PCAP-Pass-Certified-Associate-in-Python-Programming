# %% [markdown]
# # A1
#
# ## running a module from cli

# %%
python main.py
# Out:
#   Cell In[2], line 1
#     python main.py
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # A2
#
# ## importing module into main

# %% [markdown]
# ### WHen a module is executed, all of its contents are executed by python even though they aren't directly invoked

# %% [markdown]
# # A3
#
# ## Most modules contain only function and variable definitions,because they would be printed to the output otherwise

# %% [markdown]
# # A4
#
# ## Initializing
#
# ### Each module is initialized once, python ports all the contents of an imported module into memory

# %% [markdown]
# # A5
#
# ## __name__

# %% [markdown]
# ## '__ __name__ __'

# %% [markdown]
# ### if the module is executed directly it's internal \_\_name\_\_ is "\_\_main\_\_"
# ### if indirectly - then it's name is the name of the module

# %% [markdown]
# # A6
#
# ## private and public variables

# %% [markdown]
# Python does not have explicit private variables, only uses a naming convention:
#
# _private_var
#
# __private_var_2
