# %% [markdown]
# # A1

# %% [markdown]
# decomposition:
#
# dividing the code as it grows over time

# %% [markdown]
# sys - system specific parameters and functions

# %% [markdown]
# sys module

# %% [markdown]
# # A2

# %% [markdown]
# sys module

# %% [markdown]
# # A3

# %% [markdown]
# Modules:
#
# After impoting you can utilize all functions and entities in a given module

# %% [markdown]
# # A4

# %% [markdown]
# docs.python.org/library

# %% [markdown]
# Online library containing all recognized python modules
