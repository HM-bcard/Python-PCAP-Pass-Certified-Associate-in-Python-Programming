# %% [markdown]
# # A1
#
# ## MAth module: contains:

# %%
import math

for name in dir(math):
    print(name,end='\nl')
# Out:
# __doc__
# l__loader__
# l__name__
# l__package__
# l__spec__
# lacos
# lacosh
# lasin
# lasinh
# latan
# latan2
# latanh
# lcbrt
# lceil
# lcomb
# lcopysign
# lcos
# lcosh
# ldegrees
# ldist
# le
# lerf
# lerfc
# lexp
# lexp2
# lexpm1
# lfabs
# lfactorial
# lfloor
# lfmod
# lfrexp
# lfsum
# lgamma
# lgcd
# lhypot
# linf
# lisclose
# lisfinite
# lisinf
# lisnan
# lisqrt
# llcm
# lldexp
# llgamma
# llog
# llog10
# llog1p
# llog2
# lmodf
# lnan
# lnextafter
# lperm
# lpi
# lpow
# lprod
# lradians
# lremainder
# lsin
# lsinh
# lsqrt
# ltan
# ltanh
# ltau
# ltrunc
# lulp
# l

# %% [markdown]
# # A2
#
# ## mandatory roundig functions on PCAP:

# %% [markdown]
# ceil(),floor(),trunc()

# %% [markdown]
# example:m

# %%
print(math.ceil(-2.34))
# Out:
# -2

# %%
print(math.floor(-2.34))
# Out:
# -3

# %%
print(math.trunc(-2.34)) # removes the decimal part
# Out:
# -2

# %%
print(math.ceil(-2.0))
print(math.floor(-2.0))
print(math.trunc(-2.0))
# Out:
# -2
# -2
# -2

# %% [markdown]
# Standard rounding:

# %%
round(7.666)
# Out:
# 8

# %%
round(7.666,2)
# Out:
# 7.67

# %% [markdown]
# # A4
#
# ## factorial

# %%
math.factorial(3) # 3*2*1
# Out:
# 6

# %% [markdown]
# # A5
#
# ## The square root(sqrt)

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
math.sqrt(-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 math.sqrt(-4)
#
# ValueError: math domain error

# %%
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# # A7
#
# ## Hypothenuse - hypot

# %%
math.hypot(3,4)
# Out:
# 5.0
