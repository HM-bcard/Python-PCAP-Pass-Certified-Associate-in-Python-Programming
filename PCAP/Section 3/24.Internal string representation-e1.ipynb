# %% [markdown]
# # A1
#
# ## ASCII encoding of characters

# %% [markdown]
# # A2
#
# ## a code point is:

# %% [markdown]
# a numerical representation of a character

# %% [markdown]
# # A3
#
# ## ascii code pages

# %% [markdown]
# ### they contain pages with additional language groups

# %% [markdown]
# # A4
#
# ## internalization : i18n

# %% [markdown]
# # A5
#
# ## Unicode encoding - where there is a need for a uniform encoding for all languages, unicode stores 1 000 000 characters w/o code pages

# %% [markdown]
# ### first 128 chars identical with ASCII
# ### 17 different planes

# %% [markdown]
# # A6
#
# ## implementing unicode
#
# UTF-32/USC-4
#
# -one of the possible Unicode implementations
# -32 bits per character
#
# -USC-4 takes a lot of memory

# %% [markdown]
# # A7
#
# ## another Unicode implementation standard : UTF-8

# %% [markdown]
# ###-compatible with ASCII
# ### - uses as many bits as needed (8 to 32 bits)
# ### - each ASCII character in UTF-8 has 8 bits
# ### - fully supported by python
