# %% [markdown]
# # A1
# ## comparison operators:

# %% [markdown]
#  ==
#
#  !=
#
#  \>
#
#  <
#
#  \>=
#
#  <=

# %% [markdown]
# ### What does it mean internally that a string is equal or not?

# %%
'Python' == 'Python'
# Out:
# True

# %%
'Python' == 'python'
# Out:
# False

# %% [markdown]
# # A1
# ## Python compares the strings until the first difference and outputs the larger codepoint string(character)

# %% [markdown]
# # A2
# ## Python compares the string len successively - and outputs the longer string

# %%
'Pythonista' > 'python'
# Out:
# False

# %%
'Pythonista' > 'Python'
# Out:
# True

# %% [markdown]
# # A3
# ## Comparison between strings and integers only works for '==' and '!=' operators:

# %%
'a' != 97
# Out:
# True

# %%
'A' != 97
# Out:
# True

# %%
ord('a')
# Out:
# 97
