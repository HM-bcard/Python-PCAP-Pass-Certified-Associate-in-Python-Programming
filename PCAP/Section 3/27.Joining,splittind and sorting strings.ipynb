# %% [markdown]
# # A1
#
# ## join() mrthod

# %%
### syntax:

''.join(['a','list','of','strings'])
# Out:
# 'alistofstrings'

# %% [markdown]
# # A2
#
# ## split() function

# %%
### splits a string into a list of smaller strings: assumes the string is split by whitespaces - but the separater can be adjusted

# %%
'what about this'.split()
# Out:
# ['what', 'about', 'this']

# %%
'what,about,this'.split()
# Out:
# ['what,about,this']

# %%
'what,about,this'.split(',') # adjusted separator
# Out:
# ['what', 'about', 'this']

# %% [markdown]
# # A3.x
#
# ## sorting - larger topic

# %%
a_list = ['g','2','f','4','a','b','c','abc']

# %% [markdown]
# # A3.1 - sorted - makes a new list from the input lists elements

# %%
names_sorted = sorted(a_list)
print(names_sorted)
# Out:
# ['2', '4', 'a', 'abc', 'b', 'c', 'f', 'g']

# %% [markdown]
# # A3.2 - sort - changes the list that is supplied as the argument

# %%
a_list.sort()

# %%
print(a_list)
# Out:
# ['2', '4', 'a', 'abc', 'b', 'c', 'f', 'g']
