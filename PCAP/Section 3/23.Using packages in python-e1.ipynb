# %% [markdown]
# # A1
#
# ## what is a python package

# %% [markdown]
# ### o container for similar modules - this way you can organize modules into cathegories

# %% [markdown]
# # A2
#
# ## creating packages

# %% [markdown]
# ### creating a python folder and naming it - later supplying modules

# %% [markdown]
# # A3
#
# ## subpackages

# %% [markdown]
# Python will automatically treat sub-folder(subdirectoreis)
# as packages

# %% [markdown]
# # A4
#
# # \_\_init\_\_.py

# %% [markdown]
# ### It's a special file that you can add in a package directly - it can be used to initialize the package

# %% [markdown]
# ### Now it's optional - used to be required for a directory to be treated as a package - by python . Isn't required since python 3.3

# %% [markdown]
# # A5
#
# ## python dir()

# %% [markdown]
# lists all available modules
