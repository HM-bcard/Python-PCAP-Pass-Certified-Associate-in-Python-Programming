# %% [markdown]
# # A1
#
# ## jupyter lab

# %% [markdown]
# ### it's an ide based on jupyter labs architecture allowing to utilize multiple files and modules

# %% [markdown]
# # A2
#
# ## Anaconda navigator

# %% [markdown]
# ### a tool allowing to switch between multiple python adjacent ide's and service programs
