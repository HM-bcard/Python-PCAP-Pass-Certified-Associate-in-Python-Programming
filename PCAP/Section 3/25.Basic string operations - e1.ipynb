# %% [markdown]
# # A1
# ## string length : len()

# %%
len('7 chars')
# Out:
# 7

# %%
len('')
# Out:
# 0

# %% [markdown]
# # A2
#
# ## square brackets for indexing

# %%
print('substring1'[1])
# Out:
# u

# %% [markdown]
# # A3
# ## longer substrings

# %%
print('substringspan'[1:]) # from 1 till end
# Out:
# ubstringspan

# %%
print('substringspan'[:1]) # beginning to second exclusive
# Out:
# s

# %%
print('substringspan'[:]) # the entire string
# Out:
# substringspan

# %%
print('substringspan'[1:3])
# Out:
# ub

# %% [markdown]
# # A4
# ## escape characters

# %%
print("I\'m an escape character\r") # backslash is an escape characters
# Out:
# I'm an escape character

# %% [markdown]
# # A5
#
# ## a function for retrieving characters codepoint : ord()

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# # A6
#
# ## checking which character is under a specific codepoint : chr()

# %%
chr(666)
# Out:
# 'ʚ'

# %% [markdown]
# # A7
#
# ## multiline strings need triple quotes

# %%
string1 = '''newline string

end

now'''

# %%
print(string1)
# Out:
# newline string
#
# end
#
# now

# %% [markdown]
# # A8
#
# ## len function counting the line break (and other white chars)

# %%
len(string1)
# Out:
# 24

# %% [markdown]
# 20 alphanumeric, 4 distances

# %% [markdown]
# # A9
#
# ## quick concatenation:

# %%
'aaa'+'bbb'
# Out:
# 'aaabbb'

# %% [markdown]
# # A10
#
# ## string multiplication

# %%
'aaa' * 3
# Out:
# 'aaaaaaaaa'

# %% [markdown]
# # A11
#
# ## utilizing the '+' operator for concatenation is done using an occurence called 'operator overloading'

# %% [markdown]
# # A12
#
# ## non-commutative

# %%
'bbb' + 'aaa' != 'aaa' + 'bbb'
# Out:
# True

# %% [markdown]
# # A13
#
# ## string splitting with a for loop:

# %%
for c in 'string':
    print(c,end='#')
# Out:
# s#t#r#i#n#g#

# %% [markdown]
# # A14
#
# ## Python strings are immutable, you can only reassign

# %%
string1 = 'abc'

# %%
del string1[:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 del string1[:1]
#
# TypeError: 'str' object does not support item deletion

# %%
# A15 

## finding the lowest and highest value character in a string

# %%
min('string')
# Out:
# 'g'

# %%
max('string')
# Out:
# 't'

# %%
min('Astring')
# Out:
# 'A'

# %%
min('astring')
# Out:
# 'a'

# %%
max('astring')
# Out:
# 't'

# %%
max('Astring')
# Out:
# 't'
