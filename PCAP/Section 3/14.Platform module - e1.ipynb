# %% [markdown]
# # A1
#
# ## Python program's environment:

# %% [markdown]
# your code ->
#
# Python->
#
# OS ->
#
# hardware

# %% [markdown]
# # A2
# ## importing platform module

# %%
import platform

# %% [markdown]
# # A3
#
# ## platform.platform()

# %% [markdown]
# ### it prints a string identyifying the platform you're on

# %%
platform.platform()
# Out:
# 'Windows-10-10.0.26200-SP0'

# %% [markdown]
# # A4
# ## aliased platform:

# %%
platform.platform(aliased=True,terse=True)
# Out:
# 'Windows-10'

# %% [markdown]
# # A5
#
# ## platform.machine()

# %% [markdown]
# ### displays the hardware

# %%
platform.machine()
# Out:
# 'AMD64'

# %% [markdown]
# # A6
#
# ## platform.processor()

# %% [markdown]
# ### diplays the processor model

# %%
platform.processor()
# Out:
# 'AMD64 Family 25 Model 80 Stepping 0, AuthenticAMD'

# %% [markdown]
# # A7
#
# ## platform.system()

# %% [markdown]
# ### returns the general os

# %%
platform.system()
# Out:
# 'Windows'

# %% [markdown]
# # A8
#
# ## python implementation - returns python interpreter being used

# %%
platform.python_implementation()
# Out:
# 'CPython'

# %% [markdown]
# # A9
#
# ## python version tuple

# %% [markdown]
# displays the currently used python version

# %%
platform.python_version_tuple()
# Out:
# ('3', '11', '5')

# %%
platform.python_version()
# Out:
# '3.11.5'

# %% [markdown]
# # A10
#
# ## platform version

# %%
platform.version()
# Out:
# '10.0.26200'
